# %% [markdown]
# # Project 4 - Act
#
# On this document i will explain the Analyze and plot i did on this project.
#
#
# Context
# called act_report.pdf or act_report.html that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %%
from IPython.display import Image

# %% [markdown]
# ## First Insight - Distribution of Dog Ratings
#
# **Motivation"**
# Dog Ratings is our target feature, our dependent variable. I created a collumn to see on an easiest way the true values. To understand this score, i decidec plot a histogram and analyze its distribution. i am trying to find if this is a normal distribution.
#
# The Code: plt.hist(df_merge2['Dog_Ratings']);
#
# **Results**
# At First i had problems with the plot, because it has outliers, and has distorted the plot

# %%
Image(filename='Distribution_1.png',width=500,height=500)

# %% [markdown]
# **New Results**
#
# The new histogram lookalike a little skewed to left, and don't look a normal distribution.

# %%
Image(filename='Distribution_2.png',width=500,height=500)

# %% [markdown]
# ## Second Insight - Relation Between Favorite_count and Dogs_Ratings
#
# **Motivation"**
# I want to explore more features that maybe has any relationship with Dogs Ratings- the new collumn. Did i find any evidence of relationship between favorite_count and dogs_ratings?
#
# **Results**
# Again, of course, the outliers distorted our plot. And any relationship was found on this plot. for trying seeing, i used the dataset of the insight on previously question.

# %%
Image(filename='scatter_1.png',width=500,height=500)

# %% [markdown]
# **New Results**
#
# At 1.0 until 1.3 rates, we can see a positive relationship, but after this value, it seems a negative relationship. Due that we can't found any clearly relationship.

# %%
Image(filename='scatter_2.png',width=500,height=500)

# %% [markdown]
# ## Third Insight - Names and Dog_Ratings
#
# **Motivation"**
# Just a curious question: Does names can influence the Dog_Ratings?
#
# **Resultss**
# I found a great outlier on the names and their dog ratings score.

# %%
Image(filename='dogs_1.png',width=500,height=500)

# %%
Image(filename='dogs_2.png',width=500,height=500)
